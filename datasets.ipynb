# %%
import pandas as pd

# %% [markdown]
# # Importation des bases de données pour le projet depuis data.gouv

# %% [markdown]
# #### Base disparité des niveaux de vie

# %%
# URL directe du fichier
url = "https://www.data.gouv.fr/api/1/datasets/r/84e9ee7b-fc35-4c4a-85bf-85a1ff9503f4"
# Lecture avec encodage adapté
df1 = pd.read_excel(url, engine='openpyxl', header = 5, nrows=101).dropna()
# Vérification
df1
# Out:
#    Départements                                Unnamed: 1  \
# 0            01                                       Ain
# 1            02                                     Aisne
# 2            03                                    Allier
# 3            04                   Alpes-de-Haute-Provence
# 4            05                              Hautes-Alpes
# ..          ...                                       ...
# 95           95                                Val-d'Oise
# 96            P  France métropolitaine hors Ile-de-France
# 97            M                     France métropolitaine
# 98          972                                Martinique
# 99          974                                La Réunion
#
#     Rapport interdécile D9/D1
# 0                         3.5
# 1                         3.1
# 2                         3.0
# 3                         3.2
# 4                         3.0
# ..                        ...
# 95                        3.7
# 96                        3.2
# 97                        3.4
# 98                        4.2
# 99                        4.3
#
# [100 rows x 3 columns]

# %% [markdown]
# #### Base Niveau de vie des ménages (2021 - MaJ 2024)

# %%
# URL directe du fichier
url = "https://www.data.gouv.fr/api/1/datasets/r/06234b8a-f19b-4972-84e2-39e7b65e4e5a"
# Lecture avec encodage adapté
df2 = pd.read_excel(url, engine='openpyxl', header = 5, nrows=101).dropna()
# Vérification
df2
# Out:
#     Départements                                Unnamed: 1  \
# 0             01                                       Ain
# 1             02                                     Aisne
# 2             03                                    Allier
# 3             04                   Alpes-de-Haute-Provence
# 4             05                              Hautes-Alpes
# ..           ...                                       ...
# 95            95                                Val-d'Oise
# 96             P  France métropolitaine hors Ile-de-France
# 97             M                     France métropolitaine
# 99           972                                Martinique
# 100          974                                La Réunion
#
#      Niveau de vie médian
# 0                 24810.0
# 1                 20920.0
# 2                 21500.0
# 3                 21790.0
# 4                 22010.0
# ..                    ...
# 95                23290.0
# 96                22730.0
# 97                23080.0
# 99                19770.0
# 100               17070.0
#
# [100 rows x 3 columns]

# %% [markdown]
# #### Base jeunes non diplomés de 25-34 ans (2021 - MaJ 2024)

# %%
# URL directe du fichier
url = "https://www.data.gouv.fr/api/1/datasets/r/fb6e85bc-0ebe-4754-bdc4-2f3ff8c0ad8a"
# Lecture avec encodage adapté
df3 = pd.read_excel(url, engine='openpyxl', header = 4, nrows=101, usecols=[0,1,7]).dropna()
# Vérification
df3
# Out:
#     Départements                                Unnamed: 1 Unnamed: 7
# 1             01                                       Ain       11.5
# 2             02                                     Aisne       17.6
# 3             03                                    Allier       14.8
# 4             04                   Alpes-de-Haute-Provence       12.7
# 5             05                              Hautes-Alpes        9.7
# ..           ...                                       ...        ...
# 96            93                         Seine-Saint-Denis       18.9
# 97            94                              Val-de-Marne       11.3
# 98            95                                Val-d'Oise       14.1
# 99             P  France métropolitaine hors Ile-de-France       11.9
# 100            M                     France métropolitaine       11.6
#
# [100 rows x 3 columns]

# %% [markdown]
# #### Intensité de la pauvreté (2021 - MaJ 2024)

# %%
# URL directe du fichier
url = "https://www.data.gouv.fr/api/1/datasets/r/2ee6cff1-efeb-4739-bde3-d1778bea8b86"
# Lecture avec encodage adapté
df4 = pd.read_excel(url, engine='openpyxl', header = 5, nrows=101, usecols=[0,1,2]).dropna()
# Vérification
df4
# Out:
#    Départements                                Unnamed: 1  \
# 0            01                                       Ain
# 1            02                                     Aisne
# 2            03                                    Allier
# 3            04                   Alpes-de-Haute-Provence
# 4            05                              Hautes-Alpes
# ..          ...                                       ...
# 95           95                                Val-d'Oise
# 96            P  France métropolitaine hors Ile-de-France
# 97            M                     France métropolitaine
# 98          972                                Martinique
# 99          974                                La Réunion
#
#     Intensité de la pauvreté (1)
# 0                           20.4
# 1                           20.1
# 2                           20.1
# 3                           20.5
# 4                           19.9
# ..                           ...
# 95                          22.9
# 96                          20.2
# 97                          20.8
# 98                          24.1
# 99                          24.0
#
# [100 rows x 3 columns]

# %% [markdown]
# #### Taux de chomage (2019,2021,2024)

# %%
# URL directe du fichier
url = "https://www.data.gouv.fr/api/1/datasets/r/500d1954-9849-479b-9aac-85435c6d422f"
# Lecture avec encodage adapté
df5 = pd.read_excel(url, engine='openpyxl', header = 5, usecols=[0,1,7,10,12],
 nrows=101, sheet_name="Moyenne annuelle").dropna()
# Vérification
df5
# Out:
#     Département               Unnamed: 1    2019    2022    2024
# 0            01                      Ain   6.050   5.450   5.600
# 1            02                    Aisne  11.800  10.425  10.500
# 2            03                   Allier   9.050   7.675   7.925
# 3            04  Alpes-de-Haute-Provence  10.075   8.225   7.925
# 4            05             Hautes-Alpes   7.925   6.875   6.225
# ..          ...                      ...     ...     ...     ...
# 96            M    France métropolitaine   8.175   7.075   7.175
# 97          971               Guadeloupe  20.125  18.600  16.750
# 98          972               Martinique  16.125  12.450  12.350
# 99          973                   Guyane  17.125  13.125  16.950
# 100         974                  Réunion  21.500  18.050  17.350
#
# [101 rows x 5 columns]

# %% [markdown]
# #### Demandeurs d'emploi (Part de la population active 15-64 ans)

# %%
# URL directe du fichier
url = "https://www.data.gouv.fr/api/1/datasets/r/87b12173-d9fb-462f-b216-370439ac6d69"
# Lecture avec encodage adapté
df6 = pd.read_excel(url, engine='openpyxl', header = 4, usecols=[0,1,8],
 nrows=101, sheet_name="Données").dropna()
# Vérification
df6
# Out:
#     Départements                                Unnamed: 1  \
# 1             01                                       Ain
# 2             02                                     Aisne
# 3             03                                    Allier
# 4             04                   Alpes-de-Haute-Provence
# 5             05                              Hautes-Alpes
# ..           ...                                       ...
# 96            93                         Seine-Saint-Denis
# 97            94                              Val-de-Marne
# 98            95                                Val-d'Oise
# 99             P  France métropolitaine hors Ile-de-France
# 100            M                     France métropolitaine
#
#      Part des demandeurs d’emploi dans la population en âge de travailler (15 -64 ans) (3)
# 1                                                 10.3
# 2                                                 15.8
# 3                                                 13.7
# 4                                                 16.0
# 5                                                 15.8
# ..                                                 ...
# 96                                                14.7
# 97                                                11.2
# 98                                                12.0
# 99                                                12.7
# 100                                               12.5
#
# [100 rows x 3 columns]

# %% [markdown]
# #### Pauvreté monétaire (2021 - MaJ 2024)

# %%
# URL directe du fichier
url = "https://www.data.gouv.fr/api/1/datasets/r/ad9653b3-0ee8-4286-b94f-b86522c25c61"
# Lecture avec encodage adapté
df7 = pd.read_excel(url, engine='openpyxl', header = 4, usecols=[0,1,2],
 nrows=101).dropna()
# Vérification
df7
# Out:
#     Départements                                Unnamed: 1  \
# 1             01                                       Ain
# 2             02                                     Aisne
# 3             03                                    Allier
# 4             04                   Alpes-de-Haute-Provence
# 5             05                              Hautes-Alpes
# ..           ...                                       ...
# 96            95                                Val-d'Oise
# 97             P  France métropolitaine hors Ile-de-France
# 98             M                     France métropolitaine
# 99           972                                Martinique
# 100          974                                La Réunion
#
#      Taux de pauvreté (1)
# 1                    10.8
# 2                    18.8
# 3                    16.2
# 4                    17.1
# 5                    14.7
# ..                    ...
# 96                   17.7
# 97                   14.7
# 98                   14.9
# 99                   26.8
# 100                  36.1
#
# [100 rows x 3 columns]
